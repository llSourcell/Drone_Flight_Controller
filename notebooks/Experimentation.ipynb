# %%
import numpy as np

import tensorflow as tf 
import numpy as np 
import tensorflow.contrib.slim as slim
import gym
import random
from collections import deque
from numpy.random import normal

# %%
discount_factor = 0.9

ob_len = 3
action_len = 1
hidden_size = 16

tau = 0.05
learn_rate = 1e-3

replay_memory = deque(maxlen=1000000)

noise_std = 4
noise_rate = 0.995

# %%
normal(0, noise_std)
# Out:
# 1.071858529854959

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_rewards(x):
#     with open(output_txt) as f:
#         lines = f.readlines()
#         x = [float(line.split()[0]) for line in lines]

    fig = plt.figure()
    ax1 = fig.add_subplot(111)
    ax1.set_title("Total reward per episode")
    ax1.set_xlabel('Episode ->')
    ax1.set_ylabel('Sum Reward ->')

    ax1.plot(range(len(x)), x)
    plt.show()
    print('Mean reward over the last 5 episodes:', np.mean(x[-5:]))

# %%
plot_rewards([-random()*i*100 for i in range(50)][::-1])
# Out:
# Mean reward over the last 5 episodes: -159.127544086
